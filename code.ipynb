# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv('tmdb_5000_movies.csv', nrows=1000)
credits = pd.read_csv('tmdb_5000_credits.csv', nrows=1000)

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
credits.head(1)['cast'].values
# Out:
# array(['[{"cast_id": 242, "character": "Jake Sully", "credit_id": "5602a8a7c3a3685532001c9a", "gender": 2, "id": 65731, "name": "Sam Worthington", "order": 0}, {"cast_id": 3, "character": "Neytiri", "credit_id": "52fe48009251416c750ac9cb", "gender": 1, "id": 8691, "name": "Zoe Saldana", "order": 1}, {"cast_id": 25, "character": "Dr. Grace Augustine", "credit_id": "52fe48009251416c750aca39", "gender": 1, "id": 10205, "name": "Sigourney Weaver", "order": 2}, {"cast_id": 4, "character": "Col. Quaritch", "credit_id": "52fe48009251416c750ac9cf", "gender": 2, "id": 32747, "name": "Stephen Lang", "order": 3}, {"cast_id": 5, "character": "Trudy Chacon", "credit_id": "52fe48009251416c750ac9d3", "gender": 1, "id": 17647, "name": "Michelle Rodriguez", "order": 4}, {"cast_id": 8, "character": "Selfridge", "credit_id": "52fe48009251416c750ac9e1", "gender": 2, "id": 1771, "name": "Giovanni Ribisi", "order": 5}, {"cast_id": 7, "character": "Norm Spellman", "credit_id": "52fe48009251416c750ac9dd", "
# ...

# %%
movies.shape
# Out:
# (1000, 20)

# %%
movies = movies.merge(credits,on='title')
movies.shape
# Out:
# (1000, 23)

# %%
movies['original_language'].value_counts()
# Out:
# original_language
# en    991
# fr      4
# zh      3
# ja      1
# es      1
# Name: count, dtype: int64

# %%
# genres
# id
# keywords
# title
# overview
# cast
# crew 

movies = movies[['id','title','overview','genres','cast']]
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        1000 non-null   int64
#  1   title     1000 non-null   object
#  2   overview  1000 non-null   object
#  3   genres    1000 non-null   object
#  4   cast      1000 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 39.2+ KB

# %%
movies.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
# ...

# %%
movies.isnull().sum()
# Out:
# id          0
# title       0
# overview    0
# genres      0
# cast        0
# dtype: int64

# %%
#movies.dropna(inplace=True)
#movies.duplicated().sum()

# %%
movies.iloc[0]['genres']
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
import ast
def convert(obj):
    L = []
    for i in ast.literal_eval(obj):
        L.append(i['name'])
    return L

# %%
movies['genres'] = movies['genres'].apply(convert)

# %%
movies['genres']
# Out:
# 0      [Action, Adventure, Fantasy, Science Fiction]
# 1                       [Adventure, Fantasy, Action]
# 2                         [Action, Adventure, Crime]
# 3                   [Action, Crime, Drama, Thriller]
# 4               [Action, Adventure, Science Fiction]
#                            ...
# 995                        [Fantasy, Drama, Romance]
# 996                 [Comedy, Crime, Drama, Thriller]
# 997                                         [Comedy]
# 998                                  [Comedy, Crime]
# 999        [Comedy, Drama, Romance, Science Fiction]
# Name: genres, Length: 1000, dtype: object

# %%
movies.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
#movies['keywords'] = movies['keywords'].apply(convert)
#movies['keywords']

# %%
movies['cast'][0]
# Out:
# '[{"cast_id": 242, "character": "Jake Sully", "credit_id": "5602a8a7c3a3685532001c9a", "gender": 2, "id": 65731, "name": "Sam Worthington", "order": 0}, {"cast_id": 3, "character": "Neytiri", "credit_id": "52fe48009251416c750ac9cb", "gender": 1, "id": 8691, "name": "Zoe Saldana", "order": 1}, {"cast_id": 25, "character": "Dr. Grace Augustine", "credit_id": "52fe48009251416c750aca39", "gender": 1, "id": 10205, "name": "Sigourney Weaver", "order": 2}, {"cast_id": 4, "character": "Col. Quaritch", "credit_id": "52fe48009251416c750ac9cf", "gender": 2, "id": 32747, "name": "Stephen Lang", "order": 3}, {"cast_id": 5, "character": "Trudy Chacon", "credit_id": "52fe48009251416c750ac9d3", "gender": 1, "id": 17647, "name": "Michelle Rodriguez", "order": 4}, {"cast_id": 8, "character": "Selfridge", "credit_id": "52fe48009251416c750ac9e1", "gender": 2, "id": 1771, "name": "Giovanni Ribisi", "order": 5}, {"cast_id": 7, "character": "Norm Spellman", "credit_id": "52fe48009251416c750ac9dd", "gender"
# ...

# %%
def convert1(obj):
    L = []
    counter = 0
    for i in ast.literal_eval(obj):
        if counter != 1:
            L.append(i['name'])
            counter += 1
        else:
            break
        
    return L

# %%
movies['cast'] = movies['cast'].apply(convert1)

# %%
movies['cast'][0]
# Out:
# ['Sam Worthington']

# %%
movies.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres               cast
# 0  [Action, Adventure, Fantasy, Science Fiction]  [Sam Worthington]
# 1                   [Adventure, Fantasy, Action]      [Johnny Depp]
# 2                     [Action, Adventure, Crime]     [Daniel Craig]
# ...

# %%
#import ast
#def fetch_director(obj):
#    L = []
#    for i in ast.literal_eval(obj):
#        if i['job'] == 'Director':
#           L.append(i['name'])
#   return L

# %%
#movies['crew'] = movies['crew'].apply(fetch_director)
#movies['crew']

# %%
movies['overview'] = movies['overview'].apply(lambda x:x.split())

# %%
movies.head(6)
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
# 5     559                              Spider-Man 3
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
# 5  [The, seemingly, invincible, Spider-Man, goes,...
#
#                                           genres               cast
# 0  [Action, Adventure, Fantasy, Science Fiction]  [Sam Worthington]
# 1                   [Adventure, Fantasy, Action]      [Johnny Depp]
# ...

# %%
movies['genres'] = movies['genres'].apply(lambda x:[i.replace(" ","") for i in x])
#movies['crew'] = movies['crew'].apply(lambda x:[i.replace(" ","") for i in x])
#movies['keywords'] = movies['keywords'].apply(lambda x:[i.replace(" ","") for i in x])
movies['cast'] = movies['cast'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
movies.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres              cast
# 0  [Action, Adventure, Fantasy, ScienceFiction]  [SamWorthington]
# 1                  [Adventure, Fantasy, Action]      [JohnnyDepp]
# 2                    [Action, Adventure, Crime]     [DanielCraig]
# ...

# %%
movies['tags'] =  movies['genres'] + movies['cast'] + movies['overview']

# %%
movies.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres              cast  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]  [SamWorthington]
# 1                  [Adventure, Fantasy, Action]      [JohnnyDepp]
# 2                    [Action, Adventure, Crime]     [DanielCraig]
# ...

# %%
new_df = movies[['id','title','tags']]

# %%
new_df.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 tags
# 0  [Action, Adventure, Fantasy, ScienceFiction, S...
# 1  [Adventure, Fantasy, Action, JohnnyDepp, Capta...
# 2  [Action, Adventure, Crime, DanielCraig, A, cry...
# 3  [Action, Crime, Drama, Thriller, ChristianBale...
# 4  [Action, Adventure, ScienceFiction, TaylorKits...

# %%
new_df.shape
# Out:
# (1000, 3)

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))
# Out:
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_1712\3089450492.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))

# %%
new_df['tags'][0]
# Out:
# 'Action Adventure Fantasy ScienceFiction SamWorthington In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())
# Out:
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_1712\3214958533.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())

# %%
new_df['tags'][0]
# Out:
# 'action adventure fantasy sciencefiction samworthington in the 22nd century, a paraplegic marine is dispatched to the moon pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'

# %%
import nltk
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y = []
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
new_df['tags'] = new_df['tags'].apply(stem)
# Out:
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_1712\3213734980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(stem)

# %%
new_df['tags']
# Out:
# 0      action adventur fantasi sciencefict samworthin...
# 1      adventur fantasi action johnnydepp captain bar...
# 2      action adventur crime danielcraig a cryptic me...
# 3      action crime drama thriller christianbal follo...
# 4      action adventur sciencefict taylorkitsch john ...
#                              ...
# 995    fantasi drama romanc aldenehrenreich ethan wat...
# 996    comedi crime drama thriller robinwilliam tell ...
# 997    comedi benstil derek and hansel are model agai...
# 998    comedi crime owenwilson a small-tim con artist...
# 999    comedi drama romanc sciencefict garryshandl a ...
# Name: tags, Length: 1000, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=1000,stop_words='english')

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()

# %%
vectors.shape
# Out:
# (1000, 1000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %%
similarity.shape
# Out:
# (1000, 1000)

# %%
sorted(list(enumerate(similarity[0])),reverse =True,key=lambda x:x[1])
# Out:
# [(0, 1.0000000000000002),
#  (61, 0.3571428571428572),
#  (31, 0.3563483225498992),
#  (172, 0.33806170189140666),
#  (507, 0.33436692754521175),
#  (200, 0.32732683535398865),
#  (208, 0.32732683535398865),
#  (68, 0.3223291856101521),
#  (72, 0.314970394174356),
#  (972, 0.314970394174356),
#  (138, 0.3065696697424829),
#  (151, 0.3030457633656632),
#  (529, 0.3030457633656632),
#  (322, 0.28571428571428575),
#  (91, 0.2849014411490949),
#  (256, 0.28347335475692037),
#  (495, 0.2760262237369417),
#  (778, 0.27277236279499056),
#  (27, 0.2672612419124244),
#  (483, 0.2672612419124244),
#  (568, 0.2672612419124244),
#  (937, 0.2672612419124244),
#  (859, 0.2620712091804796),
#  (122, 0.25928148942086576),
#  (232, 0.25928148942086576),
#  (539, 0.25928148942086576),
#  (14, 0.25717224993681986),
#  (262, 0.25717224993681986),
#  (127, 0.2545875386086578),
#  (35, 0.253546276418555),
#  (98, 0.253546276418555),
#  (233, 0.253546276418555),
#  (7, 0.25253813613805265),
# ...

# %%
def recommend(movie):
    movie_index = new_df[new_df['title'] == movie].index[0]
    distances = similarity[movie_index]
    movies_list = sorted(list(enumerate(distances)),reverse =True,key=lambda x:x[1])[1:6]

    for i in movies_list:
        print(new_df.iloc[i[0]].title)
        
    return

# %%
recommend('Avatar')
# Out:
# Jupiter Ascending
# Iron Man 3
# The Twilight Saga: Breaking Dawn - Part 2
# Independence Day
# The Hunger Games: Mockingjay - Part 1

# %%
import pickle

# %%
pickle.dump(new_df,open('movies.pkl','wb'))

# %%
pickle.dump(similarity,open('similarity1.pkl','wb'))

# %%
pickle.dump(new_df.to_dict(),open('movie_dict.pkl','wb'))

# %%
new_df.to_dict()
# Out:
# {'id': {0: 19995,
#   1: 285,
#   2: 206647,
#   3: 49026,
#   4: 49529,
#   5: 559,
#   6: 38757,
#   7: 99861,
#   8: 767,
#   9: 209112,
#   10: 1452,
#   11: 10764,
#   12: 58,
#   13: 57201,
#   14: 49521,
#   15: 2454,
#   16: 24428,
#   17: 1865,
#   18: 41154,
#   19: 122917,
#   20: 1930,
#   21: 20662,
#   22: 57158,
#   23: 2268,
#   24: 254,
#   25: 597,
#   26: 271110,
#   27: 44833,
#   28: 135397,
#   29: 37724,
#   30: 558,
#   31: 68721,
#   32: 12155,
#   33: 36668,
#   34: 62211,
#   35: 8373,
#   36: 91314,
#   37: 68728,
#   38: 102382,
#   39: 20526,
#   40: 49013,
#   41: 44912,
#   42: 10193,
#   43: 534,
#   44: 168259,
#   45: 72190,
#   46: 127585,
#   47: 54138,
#   48: 81005,
#   49: 64682,
#   50: 9543,
#   51: 68726,
#   52: 38356,
#   53: 217,
#   54: 105864,
#   55: 62177,
#   56: 188927,
#   57: 10681,
#   58: 5174,
#   59: 14161,
#   60: 17979,
#   61: 76757,
#   62: 258489,
#   63: 411,
#   64: 246655,
#   65: 155,
#   66: 14160,
#   67: 15512,
# ...
